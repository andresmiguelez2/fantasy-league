# %%
import os
from pymongo import MongoClient

# %% [markdown]
# # Crear conexión a base de datos

# %%
client = MongoClient(f"mongodb://{os.getenv('MONGO_INITDB_ROOT_USERNAME')}:{os.getenv('MONGO_INITDB_ROOT_PASSWORD')}@mongodb:27017/fantasy_mongo_db?authSource=admin")
db = client["FantasyMDB"]

# %% [markdown]
# # Consultar elementos

# %%
db.footballer.count_documents({})
# Out:
# 350

# %%
db.footballer.find({"id": 266})[0].keys()
# Out:
# dict_keys(['_id', 'player_source_id', 'team', 'total_points', 'average_points', 'fixture_breakdown', 'image_binary', 'market_details', 'name', 'id'])
