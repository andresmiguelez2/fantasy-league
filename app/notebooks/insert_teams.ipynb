# %%
import os
from pymongo import MongoClient
from PIL import Image
from bson import Binary
import requests
import io
from PIL import  Image

# %%
client = MongoClient(f"mongodb://{os.getenv('MONGO_INITDB_ROOT_USERNAME')}:{os.getenv('MONGO_INITDB_ROOT_PASSWORD')}@mongodb:27017/fantasy_mongo_db?authSource=admin")
db = client["FantasyMDB"]

# %%
base_url = 'https://static.futbolfantasy.com/uploads/images/cabecera/webp/{}.webp'

# %%
def get_image_binary(image_url):
    response = requests.get(image_url)
    if response.status_code == 200:
        img_binary = Binary(response.content)
        return img_binary

# %%
for i in range(100):
    document = dict()
    document['id'] = i
    image_binary = get_image_binary(base_url.format(i))
    if not image_binary: continue
    
    image = Image.open(io.BytesIO(image_binary))
    display(image)
    document['image_binary'] = image_binary
    document['name'] = input(f"Enter team name for team {i}: ")
    # document['name']= None

    if document['name']:
        db.team.insert_one(document)

    # break
